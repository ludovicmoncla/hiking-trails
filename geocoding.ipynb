# %% [markdown]
# # Geocoding hiking trails

# %%
import warnings
warnings.filterwarnings('ignore')
import os

from perdido.geoparser import Geoparser
import gpxpy
import folium
import geojson

from spacy import displacy

# %%
txt_path = os.path.join("data", "visorando-2013", "txt")
gpx_path = os.path.join("data", "visorando-2013", "gpx")

# %%
''' function get_bbox() returns the bounding box of a given GPS trace '''
def get_bbox(gpx_filename):
    latitudes = []
    longitudes = []
    elevations = []
    gpx = gpxpy.parse(open(gpx_filename, 'r'))
    for track in gpx.tracks:
        for segment in track.segments:
            for point in segment.points:
                latitudes.append(point.latitude)
                longitudes.append(point.longitude)
                elevations.append(point.elevation)
    return str(min(longitudes))+' '+str(min(latitudes))+' '+str(max(longitudes))+' '+str(max(latitudes))


''' function display_map_gpx() display the map using the folium library '''
def display_map_gpx(gpx_filename, json_data=None):
    gpx = gpxpy.parse(open(gpx_filename, 'r'))
    points = []
    for track in gpx.tracks:
        for segment in track.segments:        
            for point in segment.points:
                points.append(tuple([point.latitude, point.longitude]))
    ave_lat = sum(p[0] for p in points)/len(points)
    ave_lon = sum(p[1] for p in points)/len(points) 

    m = folium.Map(location=[ave_lat, ave_lon], zoom_start=12)
    folium.PolyLine(points, color="red", weight=2.5, opacity=1).add_to(m)
    
    if json_data is not None:
        coords = list(geojson.utils.coords(json_data)) 

        if len(coords) > 0:

            print(str(len(coords))+" records found in gazetteer:")
            folium.GeoJson(json_data, name='Toponyms', tooltip=folium.features.GeoJsonTooltip(fields=['id', 'name', 'source'], localize=True)).add_to(m)
        else:
            print("Sorry, no records found in gazetteer for geocoding!")

    display(m)

# %%
filename = "1e_jour_de_champagny_le_haut_au_refuge_d"
txt_file = os.path.join(txt_path, filename + ".txt")
gpx_file = os.path.join(gpx_path, filename + ".gpx")

file = open(txt_file, "r")

# get the textual content from file
content = ""
for paragraph in file:
    content += paragraph
content = content.strip()
    
# get the bbox from the GPS file
bbox = get_bbox(gpx_file)

print('content: ', content)
print('bbox: ',bbox)
# Out:
# Au départ du Refuge du Bois dans la belle vallée encaissée de Champagny-le-Haut et avec en point de mire la Grande Motte, passer devant l'église et au carrefour prendre à droite. Arrivé près du torrent, le longer jusqu'au hameau de Friburge.
# Traverser le pont, puis à 200m prendre le petit sentier à gauche. Suivre ainsi le torrent jusqu'au pont du Laisonnay d'en Bas qu'il faut traverser. Passer devant le parking jusqu'au prochain pont qui enjambe la cascade de Py et prendre tout de suite à gauche le sentier abrupt qui grimpe. La pente est raide puisque l'on attaque un fort dénivelé de 1000m.
# Suivre tout le temps la cascade puis continuer après le refuge de Plaisance, franchir la cascade et contourner le cirque du Cul du Nant par la droite. Poursuivre sur ce sentier qui passe à proximité du lac du Plan Séry. Plus tard, parvenu à un Y avec vue sur le lac de La Plagne en contrebas, ne pas descendre vers le refuge du lac mais continuer par la droite.
# Le chemin reste sur le même dénivelé durant un moment et permet d'avoir tout du long un beau point de vue sur le lac de la Plagne. Le sentier remonte alors vers une crête pour croiser un peu plus loin le GR5. Prendre alors à droite puis continuer toujours tout droit jusqu'au lac de Gratteleu visible à gauche, passé une colline. 50m après le lac quitter le GR5 par la gauche et pour terminer, entamer la montée vers le refuge du Palet à quelques encablures de là.
# 6.744338 45.448394 6.861049 45.477553

# %% [markdown]
# ## Geoparsing (NER and geocoding) with Perdido
#
# https://github.com/ludovicmoncla/perdido

# %%
geoparser = Geoparser()
doc = geoparser(content)

# %%
displacy.render(doc.to_spacy_doc(), style="span", jupyter=True)
# Out:
# <span class="tex2jax_ignore"><div class="spans" style="line-height: 2.5; direction: ltr">Au
# <span style="font-weight: bold; display: inline-block; position: relative; height: 60px;">
#     départ
#
# <span style="background: #ddd; top: 40px; height: 4px; left: -1px; width: calc(100% + 2px); position: absolute;">
# </span>
#
#
# <span style="background: #ddd; top: 40px; height: 4px; border-top-left-radius: 3px; border-bottom-left-radius: 3px; left: -1px; width: calc(100% + 2px); position: absolute;">
#     <span style="background: #ddd; z-index: 10; color: #000; top: -0.5em; padding: 2px 3px; position: absolute; font-size: 0.6em; font-weight: bold; line-height: 1; border-radius: 3px">
#         MISC
#     </span>
# </span>
#
#
# </span>
#
# <span style="font-weight: bold; display: inline-block; position: relative; height: 60px;">
#     du
#
# <span style="background: #ddd; top: 40px; height: 4px; left: -1px; width: calc(100% + 2px); position: absolute;">
# </span>
#
#
# </span>
#
# <span style="font-weight: bold; display: inline-block; position: relative; height: 60px;">
#     Refuge
#
# <span style="background: #ddd; top: 40px; height: 4px; left: -1px; width: calc(100% + 2px); position: absolute;">
# </span>
#
#
# </span>
#
# <span style="font-weight: bold; display: inline-block; position: relative; height: 60px;">
#     du
#
# <span style="background: #ddd; top: 40px; height: 4px; left: -1px; width: calc(100% + 2px); position: absolute;">
# </span>
#
#
# </span>
#
# <span style="font-weight: bold; display: inline-block; position: relative; height: 77px;">
#     Bois
#
# <span style="background: #ddd; top: 40px; height: 4px; left: -1px; width: calc(100% + 2px); position: absolute;">
# </span>
#
# <span style="background: #ddd; top: 57px; height: 4px; left: -1px; width: calc(100% + 2px); position: absolute;">
# </span>
#
#
# <span style="background: #ddd; top: 57px; height: 4px; border-top-left-radius: 3px; border-bottom-left-radius: 3px; left: -1px; width: calc(100% + 2px); position: absolute;">
#     <span style="background: #ddd; z-index: 10; color: #000; top: -0.5em; padding: 2px 3px; position: absolute; font-size: 0.6em; font-weight: bold; line-height: 1; border-radius: 3px">
#         MISC
#     </span>
# </span>
#
#
# </span>
# dans la belle vallée encaissée de Champagny-le-Haut et avec en point de mire la Grande Motte , passer devant l' église et au carrefour prendre à droite . Arrivé près du torrent , le longer jusqu' au
# <span style="font-weight: bold; display: inline-block; position: relative; height: 60px;">
#     hameau
#
# <span style="background: #ff9561; top: 40px; height: 4px; left: -1px; width: calc(100% + 2px); position: absolute;">
# </span>
#
#
# <span style="background: #ff9561; top: 40px; height: 4px; border-top-left-radius: 3px; border-bottom-left-radius: 3px; left: -1px; width: calc(100% + 2px); position: absolute;">
#     <span style="background: #ff9561; z-index: 10; color: #000; top: -0.5em; padding: 2px 3px; position: absolute; font-size: 0.6em; font-weight: bold; line-height: 1; border-radius: 3px">
#         LOC
#     </span>
# </span>
#
#
# </span>
#
# <span style="font-weight: bold; display: inline-block; position: relative; height: 60px;">
#     de
#
# <span style="background: #ff9561; top: 40px; height: 4px; left: -1px; width: calc(100% + 2px); position: absolute;">
# </span>
#
#
# </span>
#
# <span style="font-weight: bold; display: inline-block; position: relative; height: 77px;">
#     Friburge
#
# <span style="background: #ff9561; top: 40px; height: 4px; left: -1px; width: calc(100% + 2px); position: absolute;">
# </span>
#
# <span style="background: #ff9561; top: 57px; height: 4px; left: -1px; width: calc(100% + 2px); position: absolute;">
# </span>
#
#
# <span style="background: #ff9561; top: 57px; height: 4px; border-top-left-radius: 3px; border-bottom-left-radius: 3px; left: -1px; width: calc(100% + 2px); position: absolute;">
#     <span style="background: #ff9561; z-index: 10; color: #000; top: -0.5em; padding: 2px 3px; position: absolute; font-size: 0.6em; font-weight: bold; line-height: 1; border-radius: 3px">
#         LOC
#     </span>
# </span>
#
#
# </span>
# . Traverser le pont , puis à 200 m prendre le petit sentier à gauche . Suivre ainsi le torrent jusqu' au
# <span style="font-weight: bold; display: inline-block; position: relative; height: 60px;">
#     pont
#
# <span style="background: #ff9561; top: 40px; height: 4px; left: -1px; width: calc(100% + 2px); position: absolute;">
# </span>
#
#
# <span style="background: #ff9561; top: 40px; height: 4px; border-top-left-radius: 3px; border-bottom-left-radius: 3px; left: -1px; width: calc(100% + 2px); position: absolute;">
#     <span style="background: #ff9561; z-index: 10; color: #000; top: -0.5em; padding: 2px 3px; position: absolute; font-size: 0.6em; font-weight: bold; line-height: 1; border-radius: 3px">
#         LOC
#     </span>
# </span>
#
#
# </span>
#
# <span style="font-weight: bold; display: inline-block; position: relative; height: 60px;">
#     du
#
# <span style="background: #ff9561; top: 40px; height: 4px; left: -1px; width: calc(100% + 2px); position: absolute;">
# </span>
#
#
# </span>
#
# <span style="font-weight: bold; display: inline-block; position: relative; height: 77px;">
#     Laisonnay
#
# <span style="background: #ff9561; top: 40px; height: 4px; left: -1px; width: calc(100% + 2px); position: absolute;">
# </span>
#
# <span style="background: #ddd; top: 57px; height: 4px; left: -1px; width: calc(100% + 2px); position: absolute;">
# </span>
#
#
# <span style="background: #ddd; top: 57px; height: 4px; border-top-left-radius: 3px; border-bottom-left-radius: 3px; left: -1px; width: calc(100% + 2px); position: absolute;">
#     <span style="background: #ddd; z-index: 10; color: #000; top: -0.5em; padding: 2px 3px; position: absolute; font-size: 0.6em; font-weight: bold; line-height: 1; border-radius: 3px">
#         MISC
#     </span>
# </span>
#
#
# </span>
# d' en Bas qu' il faut traverser . Passer devant le parking jusqu' au prochain pont qui enjambe
# <span style="font-weight: bold; display: inline-block; position: relative; height: 60px;">
#     la
#
# <span style="background: #ff9561; top: 40px; height: 4px; left: -1px; width: calc(100% + 2px); position: absolute;">
# </span>
#
#
# <span style="background: #ff9561; top: 40px; height: 4px; border-top-left-radius: 3px; border-bottom-left-radius: 3px; left: -1px; width: calc(100% + 2px); position: absolute;">
#     <span style="background: #ff9561; z-index: 10; color: #000; top: -0.5em; padding: 2px 3px; position: absolute; font-size: 0.6em; font-weight: bold; line-height: 1; border-radius: 3px">
#         LOC
#     </span>
# </span>
#
#
# </span>
#
# <span style="font-weight: bold; display: inline-block; position: relative; height: 60px;">
#     cascade
#
# <span style="background: #ff9561; top: 40px; height: 4px; left: -1px; width: calc(100% + 2px); position: absolute;">
# </span>
#
#
# </span>
#
# <span style="font-weight: bold; display: inline-block; position: relative; height: 60px;">
#     de
#
# <span style="background: #ff9561; top: 40px; height: 4px; left: -1px; width: calc(100% + 2px); position: absolute;">
# </span>
#
#
# </span>
#
# <span style="font-weight: bold; display: inline-block; position: relative; height: 77px;">
#     Py
#
# <span style="background: #ff9561; top: 40px; height: 4px; left: -1px; width: calc(100% + 2px); position: absolute;">
# </span>
#
# <span style="background: #ddd; top: 57px; height: 4px; left: -1px; width: calc(100% + 2px); position: absolute;">
# </span>
#
#
# <span style="background: #ddd; top: 57px; height: 4px; border-top-left-radius: 3px; border-bottom-left-radius: 3px; left: -1px; width: calc(100% + 2px); position: absolute;">
#     <span style="background: #ddd; z-index: 10; color: #000; top: -0.5em; padding: 2px 3px; position: absolute; font-size: 0.6em; font-weight: bold; line-height: 1; border-radius: 3px">
#         MISC
#     </span>
# </span>
#
#
# </span>
# et prendre tout de suite à gauche le sentier abrupt qui grimpe . La pente est raide puisque l' on attaque un fort dénivelé de 1000 m.
# <span style="font-weight: b

# %%
display_map_gpx(gpx_file, doc.geojson)
# Out:
# 12 records found in gazetteer:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_71d2ec1a0a923ee3bcb1c832fc969f0d {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_71d2ec1a0a923ee3bcb1c832fc969f0d&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_71d2ec1a0a923ee3bcb1c832fc969f0d = L.map(
#                 &quot;map_71d2ec1a0a923ee3bcb1c832fc969f0d&quot;,
#                 {
#                     center: [45.46411936559143, 6.811797175627238],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_e0fa33dc44961d25ff58edd52e1ae36f = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_e0fa33dc44961d25ff58edd52e1ae36f.addTo(map_71d2ec1a0a923ee3bcb1c832fc969f0d);
#
#
#             var poly_line_d272df4d9d51f6f66173d4c266d1e62b = L.polyline(
#                 [[45.458928, 6.744338], [45.460261, 6.745603], [45.459751, 6.747086], [45.458665, 6.749026], [45.457942, 6.751635], [45.457152, 6.753479], [45.456206, 6.755713], [45.4556, 6.757388], [45.455454, 6.758794], [45.455189, 6.759493], [45.454782, 6.759382], [45.454434, 6.759949], [45.453569, 6.760618], [45.453522, 6.761017], [45.453015, 6.761687], [45.452957, 6.762689], [45.452973, 6.76314], [45.453065, 6.763574], [45.452999, 6.764341], [45.453225, 6.764632], [45.453475, 6.765587], [45.453304, 6.766205], [45.452961, 6.767034], [45.452702, 6.76807], [45.452377, 6.769683], [45.452474, 6.77108], [45.452026, 6.772075], [45.451591, 6.772869], [45.451399, 6.773237], [45.451234, 6.77379], [45.450768, 6.774317], [45.450673, 6.775311], [45.45023, 6.775979], [45.450005, 6.775927], [45.449551, 6.777561], [45.449042, 6.778281], [45.448559, 6.778794], [45.448394, 6.780165], [45.448557, 6.780722], [45.448766, 6.781225], [45.449103, 6.781348], [45.449299, 6.781942], [45.449395, 6.782937], [45.449112, 6.783823], [45.448977, 6.78412], [45.449156, 6.784103], [45.449134, 6.784295], [45.449512, 6.78457], [45.449164, 6.784967], [45.449422, 6.784987], [45.449048, 6.785676], [45.44927, 6.785634], [45.449278, 6.785847], [45.449416, 6.785924], [45.44942, 6.786107], [45.
# %% [markdown]
# ## NER with spaCy
#
# https://spacy.io
#
#
# ```bash
# pip install -U pip setuptools wheel
# pip install -U 'spacy[apple]'
# python -m spacy download fr_core_news_sm
# ```

# %%
import spacy
nlp = spacy.load("fr_core_news_sm")
doc = nlp(content)

displacy.render(doc, style="ent", jupyter=True)
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">Au départ du
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Refuge du Bois
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
#  dans la belle vallée encaissée de
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Champagny-le-Haut
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
#  et avec en point de mire la
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Grande Motte
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
# , passer devant l'église et au carrefour prendre à droite. Arrivé près du torrent, le longer jusqu'au hameau de
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Friburge
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PER</span>
# </mark>
# .<br>
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Traverser
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
#  le pont, puis à 200m prendre le petit sentier à gauche. Suivre ainsi le torrent jusqu'au
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     pont du Laisonnay
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
#  d'en
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Bas
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
#  qu'il faut traverser. Passer devant le parking jusqu'au prochain pont qui enjambe la cascade de
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Py
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
#  et prendre tout de suite à gauche le sentier abrupt qui grimpe. La pente est raide puisque l'on attaque un fort dénivelé de 1000m.<br>
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Suivre
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PER</span>
# </mark>
#  tout le temps la cascade puis continuer après le
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     refuge de Plaisance
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
# , franchir la cascade et contourner le cirque du
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Cul du Nant
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
#  par la droite. Poursuivre sur ce sentier qui passe à proximité du
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     lac du Plan Séry
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
# . Plus tard, parvenu à un
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Y
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MISC</span>
# </mark>
#  avec vue sur le
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     lac de La Plagne
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
#  en contrebas, ne pas descendre vers le refuge du lac mais continuer par la droite.<br>Le chemin reste sur le même dénivelé durant un moment et permet d'avoir tout du long un beau point de vue sur le
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     lac de la Plagne
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
# . Le sentier remonte alors vers une crête pour croiser un peu plus loin le
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     GR5
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# . Prendre alors à droite puis continuer toujours tout droit jusqu'au
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     lac de Gratteleu
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
#  visible à gauche, passé une colline. 50m après le lac quitter le
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     GR5
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  par la gauche et pour terminer, entamer la montée vers le
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     refuge du Palet
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
#  à quelques encablures de là.</div></span>

# %%
locations = [ent.text for ent in doc.ents if ent.label_ == "LOC"]
locations
# Out:
# ['Refuge du Bois',
#  'Champagny-le-Haut',
#  'Grande Motte',
#  'Traverser',
#  'pont du Laisonnay',
#  'Bas',
#  'Py',
#  'refuge de Plaisance',
#  'Cul du Nant',
#  'lac du Plan Séry',
#  'lac de La Plagne',
#  'lac de la Plagne',
#  'lac de Gratteleu',
#  'refuge du Palet']

# %% [markdown]
# ## Geocoding with Perdido
#
# By default, Perdido uses the OpenStreetMap Nominatim API.

# %%
from perdido.geocoder import Geocoder

geocoder = Geocoder(bbox=bbox)
doc = geocoder(locations)

display_map_gpx(gpx_file, doc.geojson)
# Out:
# 13 records found in gazetteer:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_90336e44a01bda3ef7f2c026e78df468 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_90336e44a01bda3ef7f2c026e78df468&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_90336e44a01bda3ef7f2c026e78df468 = L.map(
#                 &quot;map_90336e44a01bda3ef7f2c026e78df468&quot;,
#                 {
#                     center: [45.46411936559143, 6.811797175627238],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_0db52b409f03970e494558172fb71318 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_
 6.807641], [45.467493, 6.808505], [45.467609, 6.809388], [45.467616, 6.810506], [45.467762, 6.811455], [45.468018, 6.811869], [45.467913, 6.812214], [45.467891, 6.812533], [45.467928, 6.812898], [45.467833, 6.813442], [45.467639, 6.813828], [45.46747, 6.814403], [45.467329, 6.814782], [45.467445, 6.814863], [45.46746, 6.815006], [45.467539, 6.815203], [45.467533, 6.815431], [45.467739, 6.816237], [45.467897, 6.816653], [4

# %%
doc.geojson
# Out:
# {'type': 'FeatureCollection',
#  'features': [{'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [6.744398, 45.459549]},
#    'properties': {'id': 0,
#     'name': 'Refuge du Bois',
#     'sourceName': 'Refuge du Bois, Rue Michel Ruffier-Lanche, Le Bois, Champagny-en-Vanoise, Albertville, Savoie, Auvergne-Rhône-Alpes, France métropolitaine, 73350, France',
#     'type': 'alpine_hut',
#     'country': 'France',
#     'source': 'nominatim'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [6.693793, 45.464146]},
#    'properties': {'id': 0,
#     'name': 'Champagny-le-Haut',
#     'sourceName': "Champagny, Rue des Hauts du Crey, L'Envers de Reclaz, La Traye, Champagny-en-Vanoise, Albertville, Savoie, Auvergne-Rhône-Alpes, France métropolitaine, 73350, France",
#     'type': 'gondola',
#     'country': 'France',
#     'source': 'nominatim'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [6.86988, 45.410791]},
#    'properties': {'id': 0,
#     'name': 'Grande Motte',
#     'sourceName': 'Grande Motte, Val-Cenis, Saint-Jean-de-Maurienne, Savoie, Auvergne-Rhône-Alpes, France métropolitaine, France',
#     'type': 'peak',
#     'country': 'France',
#     'source': 'nominatim'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-0.5296, 50.955058]},
#    'properties': {'id': 0,
#     'name': 'Traverser',
#     'sourceName': 'Traverser, Pulborough, Horsham, West Sussex, England, United Kingdom',
#     'type': 'industrial',
#     'country': 'United Kingdom',
#     'source': 'nominatim'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [6.776566, 45.449973]},
#    'properties': {'id': 0,
#     'name': 'pont du Laisonnay',
#     'sourceName': "Pont du Laisonnay, Le Laisonnay d'En Bas, Champagny-en-Vanoise, Albertville, Savoie, Auvergne-Rhône-Alpes, France métropolitaine, 73350, France",
#     'type': 'tertiary',
#     'country': 'France',
#     'source': 'nominatim'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [16.081953, 40.500571]},
#    'properties': {'id': 0,
#     'name': 'Bas',
#     'sourceName': 'Basilicata, Italia',
#     'type': 'administrative',
#     'country': 'Italia',
#     'source': 'nominatim'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-58.169345, -23.316593]},
#    'properties': {'id': 0,
#     'name': 'Py',
#     'sourceName': 'Paraguay / Paraguái',
#     'type': 'administrative',
#     'country': 'Paraguay / Paraguái',
#     'source': 'nominatim'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [6.792019, 45.462986]},
#    'properties': {'id': 0,
#     'name': 'refuge de Plaisance',
#     'sourceName': "Refuge de Plaisance, Chemin du Col du Palet, Le Laisonnay d'en Haut, Champagny-en-Vanoise, Albertville, Savoie, Auvergne-Rhône-Alpes, France métropolitaine, 73350, France",
#     'type': 'alpine_hut',
#     'country': 'France',
#     'source': 'nominatim'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [6.785132, 45.48796]},
#    'properties': {'id': 0,
#     'name': 'Cul du Nant',
#     'sourceName': 'Glacier du Cul du Nant, Champagny-en-Vanoise, Albertville, Savoie, Auvergne-Rhône-Alpes, France métropolitaine, 73350, France',
#     'type': 'glacier',
#     'country': 'France',
#     'source': 'nominatim'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [6.81815, 45.467044]},
#    'properties': {'id': 0,
#     'name': 'lac du Plan Séry',
#     'sourceName': 'Lac du Plan Séry, Champagny-en-Vanoise, Albertville, Savoie, Auvergne-Rhône-Alpes, France métropolitaine, 73350, France',
#     'type': 'water',
#     'country': 'France',
#     'source': 'nominatim'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [6.841607, 45.484253]},
#    'properties': {'id': 0,
#     'name': 'lac de La Plagne',
#     'sourceName': 'Lac de La Plagne, Peisey-Nancroix, Albertville, Savoie, Auvergne-Rhône-Alpes, France métropolitaine, 73210, France',
#     'type': 'water',
#     'country': 'France',
#     'source': 'nominatim'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [6.841607, 45.484253]},
#    'properties': {'id': 0,
#     'name': 'lac de la Plagne',
#     'sourceName': 'Lac de La Plagne, Peisey-Nancroix, Albertville, Savoie, Auvergne-Rhône-Alpes, France métropolitaine, 73210, France',
#     'type': 'water',
#     'country': 'France',
#     'source': 'nominatim'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [6.861183, 45.458296]},
#    'properties': {'id': 0,
#     'name': 'refuge du Palet',
#     'sourceName': 'Refuge du Col du Palet, 217, Tarte à Lognan, Val-Claret, Tignes, Albertville, Savoie, Auvergne-Rhône-Alpes, France métropolitaine, 74130, France',
#     'type': 'alpine_hut',
#     'country': 'France',
#     'source': 'nominatim'}}]}
